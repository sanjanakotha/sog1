# %%
import glob as glob
from IPython.display import Image, display

# %% [markdown]
# 4/4/25: Updating plots to be generated using recalculated scores with complete map.

# %% [markdown]
# # Combinatorial PSv

# %%
for imageName in glob.glob("../output/figures/combinatorial_PSv/*"):
    display(Image(filename=imageName, width = 1000))

# %% [markdown]
# # A scan

# %%
for imageName in glob.glob("../output/figures/Ascan/*"):
    display(Image(filename=imageName, width = 600))
    print()
    print()

# %% [markdown]
# # Shuffles

# %% [markdown]
# - Generated in ../notebooks/Shuffles.ipynb
# 1. Read in library entries containing "_shuffle_size" in description
# 2. Kept all shuffles (size 2, 4, 6, 8, or 10AA spaced every 2AA)
# 3. Identified indices differing from corresponding wildtype tile.
# 4. Used minimum difference and maximum difference as start/end of horizontal line. y = activity of tested tile.

# %%
for imageName in glob.glob("../output/figures/shuffles/*"):
    display(Image(filename=imageName, width = 600))
    print()
    print()

# %% [markdown]
# # [TO ADD] Shuffles split by state size + marginals

# %% [markdown]
# # All shuffles and A scans

# %%
for imageName in glob.glob("../output/figures/shuffles_and_Ascan/*"):
    display(Image(filename=imageName, width = 600))
    print()
    print()

# %% [markdown]
# # [TO ADD] Combined A scan and 4AA shuffle

# %% [markdown]
# # [TO ADD] Single confirmed PSv

# %% [markdown]
# # Conservation

# %% [markdown]
# ## Sog1 Orthologs

# %% [markdown]
# ### Aligned on DBD

# %% [markdown]
# #### AD tree
# - Used MAFFT + FastTree to obtain tree

# %%
display(Image(filename="../output/figures/conservation/DBD_protein_tree.png", width=900))

# %% [markdown]
# #### Species tree
# - Used NCBI Taxon

# %%
display(Image(filename="../output/figures/conservation/DBD_species_tree.png", width=900))

# %% [markdown]
# ### Full alignment

# %% [markdown]
# #### Protein tree

# %%
display(Image(filename="../output/figures/conservation/full_protein_tree.png", width=900))

# %% [markdown]
# #### Species tree

# %%
display(Image(filename="../output/figures/conservation/full_species_tree.png", width=900))

# %% [markdown]
# ## NAC Family

# %% [markdown]
# ### Aligned on DBD

# %%
display(Image(filename="../output/figures/conservation/nac_family/DBD_aligned.png", width=900))

# %% [markdown]
# ### Full alignment

# %%
display(Image(filename="../output/figures/conservation/nac_family/full_aligned.png", width=900))

# %% [markdown]
# # Helicity

# %% [markdown]
# ## Overview of helical predictions within Sog1:
# - Steps:
#     - I used the "dssp_helicity()" function from Sparrow to predict the helicity of the wild type Sog1 Sequence.
#     - In the top panel below, the trace is the per residue probability of helicity. The pink rectangles behind represnt areas which the function calls as helical.
#     - In the bottom panel, I ran the dssp_helicity() function on each wild type tile. I averaged the probabiltiies to get one score per tile, which is the pink trace. The blue trace is the activity measured at each center.
# - Takeaway: The N-terminal AD and first C-terminal AD both overlap predicted helical areas. This is consistent with previously annotated helices.

# %%
display(Image(filename="../output/figures/helicity/helicity_overview.png", width=800))

# %% [markdown]
# Ran dssp_helicity() on all shuffles within the following tiles. In red is the value for the corresponding wild type tile.

# %%
display(Image(filename="../output/figures/helicity/tile_33-35_avg_helicity_prob.png", width=900))
display(Image(filename="../output/figures/helicity/tile_41-42_avg_helicity_prob.png", width=600))

# %% [markdown]
# Also ran end_to_end_distance() function from Sparrow.

# %%
display(Image(filename="../output/figures/helicity/tile_33-35_end_to_end.png", width=900))
display(Image(filename="../output/figures/helicity/tile_41-42_end_to_end.png", width=600))
